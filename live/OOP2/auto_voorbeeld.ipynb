# %%
from auto import Auto

a = Auto("Toyota")
b = Auto("BMW")
# a.merk, b.merk

print(a.merk)
print(a.snelheid)
a.versnellen(50)
print(a.snelheid)
# Out:
# Toyota
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 8
#       5 # a.merk, b.merk
#       7 print(a.merk)
# ----> 8 print(a.snelheid)
#       9 a.versnellen(50)
#      10 print(a.snelheid)
#
# AttributeError: 'Auto' object has no attribute 'snelheid'
